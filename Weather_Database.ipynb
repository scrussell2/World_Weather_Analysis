# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
# print(coordinates)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# city_url = url + "&q=" + "Boston"
# print(city_url)

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        # time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | kingaroy
# Processing Record 7 of Set 1 | purbalingga
# Processing Record 8 of Set 1 | skibbereen
# Processing Record 9 of Set 1 | oriximina
# Processing Record 10 of Set 1 | port moresby
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | shenjiamen
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mehamn
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | tiznit
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | luang prabang
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | irbit
# Processing Record 24 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | ketchikan
# Processing Record 28 of Set 1 | atar
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | canavieiras
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | isla vista
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | waipawa
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | grand-santi
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | lishan
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | saint-augustin
# Processing Record 6 of Set 2 | burgeo
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | xuddur
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | bay city
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | neiafu
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | gerash
# Processing Record 24 of Set 2 | oda
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 2 | touros
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | karlskrona
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | gazi
# Processing Record 32 of Set 2 | sibolga
# Processing Record 33 of Set 2 | amga
# Processing Record 34 of Set 2 | vitim
# Processing Record 35 of Set 2 | tupik
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | nakamura
# Processing Record 38 of Set 2 | ostrovnoy
# Processing Record 39 of Set 2 | siteki
# Processing Record 40 of Set 2 | namwala
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | meulaboh
# Processing Record 44 of Set 2 | teknaf
# Processing Record 45 of Set 2 | paso de carrasco
# Processing Record 46 of Set 2 | antofagasta
# Processing Record 47 of Set 2 | san carlos de bariloche
# Processing Record 48 of Set 2 | tautira
# Processing Record 49 of Set 2 | isilkul
# Processing Record 50 of Set 2 | pacific grove
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | bonthe
# Processing Record 3 of Set 3 | panguna
# Processing Record 4 of Set 3 | constitucion
# Processing Record 5 of Set 3 | atambua
# Processing Record 6 of Set 3 | husavik
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | solnechnyy
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | yulara
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | jizan
# Processing Record 15 of Set 3 | de aar
# Processing Record 16 of Set 3 | searcy
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | noumea
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | karratha
# Processing Record 23 of Set 3 | jining
# Processing Record 24 of Set 3 | sambava
# Processing Record 25 of Set 3 | waddan
# Processing Record 26 of Set 3 | labuhan
# Processing Record 27 of Set 3 | dossor
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | porto walter
# Processing Record 31 of Set 3 | paramonga
# Processing Record 32 of Set 3 | nyurba
# Processing Record 33 of Set 3 | mount gambier
# Processing Record 34 of Set 3 | kokopo
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | santa cruz de la palma
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | rawson
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | santa catalina
# Processing Record 41 of Set 3 | khatanga
# Processing Record 42 of Set 3 | muzhi
# Processing Record 43 of Set 3 | marana
# Processing Record 44 of Set 3 | tchollire
# Processing Record 45 of Set 3 | zhigansk
# Processing Record 46 of Set 3 | damavand
# Processing Record 47 of Set 3 | giresun
# Processing Record 48 of Set 3 | vardo
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | bethel
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | inverness
# Processing Record 5 of Set 4 | manzil tamim
# City not found. Skipping...
# Processing Record 6 of Set 4 | bereda
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | yerbogachen
# Processing Record 10 of Set 4 | grand junction
# Processing Record 11 of Set 4 | vershino-shakhtaminskiy
# Processing Record 12 of Set 4 | salumbar
# Processing Record 13 of Set 4 | dubbo
# Processing Record 14 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | basco
# Processing Record 18 of Set 4 | hovd
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | lakhdenpokhya
# Processing Record 21 of Set 4 | mayo
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | punta alta
# Processing Record 24 of Set 4 | sobolevo
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | sao miguel do araguaia
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | half moon bay
# Processing Record 29 of Set 4 | guaratinga
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | zhifang
# Processing Record 32 of Set 4 | clifton
# Processing Record 33 of Set 4 | kamenka
# Processing Record 34 of Set 4 | varadero
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | imbituba
# Processing Record 37 of Set 4 | araguacu
# Processing Record 38 of Set 4 | bredasdorp
# Processing Record 39 of Set 4 | cabo san lucas
# Processing Record 40 of Set 4 | bontang
# Processing Record 41 of Set 4 | paamiut
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | villa maria
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | coshocton
# Processing Record 47 of Set 4 | ylojarvi
# Processing Record 48 of Set 4 | conceicao do araguaia
# Processing Record 49 of Set 4 | rojhan
# Processing Record 50 of Set 4 | sechura
# Processing Record 1 of Set 5 | sananduva
# Processing Record 2 of Set 5 | praia da vitoria
# Processing Record 3 of Set 5 | arman
# Processing Record 4 of Set 5 | sao jose da coroa grande
# Processing Record 5 of Set 5 | taman
# Processing Record 6 of Set 5 | xichang
# Processing Record 7 of Set 5 | eureka
# Processing Record 8 of Set 5 | camacupa
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | timra
# Processing Record 11 of Set 5 | lang suan
# Processing Record 12 of Set 5 | hervey bay
# Processing Record 13 of Set 5 | rognan
# Processing Record 14 of Set 5 | tucupita
# Processing Record 15 of Set 5 | brae
# Processing Record 16 of Set 5 | filadelfia
# Processing Record 17 of Set 5 | cairns
# Processing Record 18 of Set 5 | salinopolis
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | urumqi
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | kurumkan
# Processing Record 23 of Set 5 | ajaigarh
# Processing Record 24 of Set 5 | cap-aux-meules
# Processing Record 25 of Set 5 | pevek
# Processing Record 26 of Set 5 | peniche
# Processing Record 27 of Set 5 | mount isa
# Processing Record 28 of Set 5 | khao yoi
# Processing Record 29 of Set 5 | bukama
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | launceston
# Processing Record 32 of Set 5 | mozarlandia
# Processing Record 33 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 5 | rehoboth
# Processing Record 36 of Set 5 | wloclawek
# Processing Record 37 of Set 5 | kirakira
# Processing Record 38 of Set 5 | bucerias
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | lerwick
# Processing Record 41 of Set 5 | bubaque
# Processing Record 42 of Set 5 | bilibino
# Processing Record 43 of Set 5 | scarborough
# Processing Record 44 of Set 5 | aden
# Processing Record 45 of Set 5 | pangai
# Processing Record 46 of Set 5 | mahibadhoo
# Processing Record 47 of Set 5 | teya
# Processing Record 48 of Set 5 | ahipara
# Processing Record 49 of Set 5 | kholm
# Processing Record 50 of Set 5 | minab
# Processing Record 1 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 6 | honiara
# Processing Record 3 of Set 6 | ukiah
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | moose factory
# Processing Record 7 of Set 6 | namatanai
# Processing Record 8 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 6 | guanare
# Processing Record 10 of Set 6 | princeton
# Processing Record 11 of Set 6 | buin
# Processing Record 12 of Set 6 | melfort
# Processing Record 13 of Set 6 | bridlington
# Processing Record 14 of Set 6 | anantapur
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | xining
# Processing Record 17 of Set 6 | maun
# Processing Record 18 of Set 6 | victor harbor
# Processing Record 19 of Set 6 | saint george
# Processing Record 20 of Set 6 | oyem
# Processing Record 21 of Set 6 | qobustan
# Processing Record 22 of Set 6 | rio gallegos
# Processing Record 23 of Set 6 | nelson bay
# Processing Record 24 of Set 6 | hokitika
# Processing Record 25 of Set 6 | mayumba
# Processing Record 26 of Set 6 | jambi
# Processing Record 27 of Set 6 | senanga
# Processing Record 28 of Set 6 | muros
# Processing Record 29 of Set 6 | kapuskasing
# Processing Record 30 of Set 6 | aykhal
# Processing Record 31 of Set 6 | mahebourg
# Processing Record 32 of Set 6 | dali
# Processing Record 33 of Set 6 | alta floresta
# Processing Record 34 of Set 6 | pampierstad
# Processing Record 35 of Set 6 | hatillo
# Processing Record 36 of Set 6 | manakara
# Processing Record 37 of Set 6 | jibuti
# Processing Record 38 of Set 6 | myaundzha
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | jaguaruna
# Processing Record 41 of Set 6 | dingle
# Processing Record 42 of Set 6 | tuatapere
# Processing Record 43 of Set 6 | santiago del estero
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | kalabo
# Processing Record 46 of Set 6 | marquette
# Processing Record 47 of Set 6 | mackenzie
# Processing Record 48 of Set 6 | almaznyy
# Processing Record 49 of Set 6 | ferme-neuve
# Processing Record 50 of Set 6 | lubango
# Processing Record 1 of Set 7 | sitka
# Processing Record 2 of Set 7 | klaksvik
# Processing Record 3 of Set 7 | volksrust
# Processing Record 4 of Set 7 | alice springs
# Processing Record 5 of Set 7 | pontianak
# Processing Record 6 of Set 7 | byron bay
# Processing Record 7 of Set 7 | portland
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | catuday
# Processing Record 10 of Set 7 | de-kastri
# Processing Record 11 of Set 7 | kruisfontein
# Processing Record 12 of Set 7 | price
# Processing Record 13 of Set 7 | onda
# Processing Record 14 of Set 7 | college
# Processing Record 15 of Set 7 | pangnirtung
# Processing Record 16 of Set 7 | seoul
# Processing Record 17 of Set 7 | west plains
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | charters towers
# Processing Record 20 of Set 7 | graaff-reinet
# Processing Record 21 of Set 7 | gazanjyk
# Processing Record 22 of Set 7 | clyde river
# Processing Record 23 of Set 7 | kadayanallur
# Processing Record 24 of Set 7 | pangoa
# Processing Record 25 of Set 7 | nanortalik
# Processing Record 26 of Set 7 | ugep
# Processing Record 27 of Set 7 | san cristobal
# Processing Record 28 of Set 7 | la ronge
# Processing Record 29 of Set 7 | kuytun
# Processing Record 30 of Set 7 | broken hill
# Processing Record 31 of Set 7 | korla
# Processing Record 32 of Set 7 | jeremie
# Processing Record 33 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 7 | dunmore town
# Processing Record 35 of Set 7 | alugan
# Processing Record 36 of Set 7 | tungor
# Processing Record 37 of Set 7 | poum
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | narsaq
# Processing Record 40 of Set 7 | bandarbeyla
# Processing Record 41 of Set 7 | gladstone
# Processing Record 42 of Set 7 | comodoro rivadavia
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | point fortin
# Processing Record 45 of Set 7 | aldama
# Processing Record 46 of Set 7 | chinavita
# Processing Record 47 of Set 7 | alexandria
# Processing Record 48 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 49 of Set 7 | zamora
# Processing Record 50 of Set 7 | port hardy
# Processing Record 1 of Set 8 | anadyr
# Processing Record 2 of Set 8 | sistranda
# Processing Record 3 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 8 | udachnyy
# Processing Record 5 of Set 8 | plouzane
# Processing Record 6 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 8 | san quintin
# Processing Record 8 of Set 8 | port lincoln
# Processing Record 9 of Set 8 | huilong
# Processing Record 10 of Set 8 | aginskoye
# Processing Record 11 of Set 8 | manado
# Processing Record 12 of Set 8 | codrington
# Processing Record 13 of Set 8 | kahului
# Processing Record 14 of Set 8 | port shepstone
# Processing Record 15 of Set 8 | praia
# Processing Record 16 of Set 8 | gat
# Processing Record 17 of Set 8 | vestmannaeyjar
# Processing Record 18 of Set 8 | smirnykh
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | marienburg
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | fare
# Processing Record 23 of Set 8 | hofn
# Processing Record 24 of Set 8 | paita
# Processing Record 25 of Set 8 | san jose
# Processing Record 26 of Set 8 | ahuimanu
# Processing Record 27 of Set 8 | martil
# Processing Record 28 of Set 8 | vangaindrano
# Processing Record 29 of Set 8 | xinmin
# Processing Record 30 of Set 8 | drummondville
# Processing Record 31 of Set 8 | cerrito
# Processing Record 32 of Set 8 | bayonet point
# Processing Record 33 of Set 8 | green river
# Processing Record 34 of Set 8 | avera
# Processing Record 35 of Set 8 | kitimat
# Processing Record 36 of Set 8 | pangody
# Processing Record 37 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 8 | stepnyak
# Processing Record 39 of Set 8 | nioro
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | boguchany
# Processing Record 42 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 8 | san-pedro
# Processing Record 44 of Set 8 | san antero
# Processing Record 45 of Set 8 | kavaratti
# Processing Record 46 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 47 of Set 8 | pucara
# Processing Record 48 of Set 8 | piryion
# City not found. Skipping...
# Processing Record 49 of Set 8 | vaitape
# Processing Record 50 of Set 8 | kloulklubed
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | carutapera
# Processing Record 3 of Set 9 | kasangulu
# Processing Record 4 of Set 9 | krasnoselkup
# Processing Record 5 of Set 9 | samarinda
# Processing Record 6 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 9 | bolshoye pikino
# City not found. Skipping...
# Processing Record 8 of Set 9 | havre-saint-pierre
# Processing Record 9 of Set 9 | fortuna
# Processing Record 10 of Set 9 | bemidji
# Processing Record 11 of Set 9 | argelia
# Processing Record 12 of Set 9 | luderitz
# Processing Record 13 of Set 9 | melipilla
# Processing Record 14 of Set 9 | santa ana
# Processing Record 15 of Set 9 | benjamin aceval
# Processing Record 16 of Set 9 | kyra
# Processing Record 17 of Set 9 | puerto boyaca
# Processing Record 18 of Set 9 | saskylakh
# Processing Record 19 of Set 9 | burica
# City not found. Skipping...
# Processing Record 20 of Set 9 | nushki
# Processing Record 21 of Set 9 | sakaiminato
# Processing Record 22 of Set 9 | satun
# Processing Record 23 of Set 9 | siuna
# Processing Record 24 of Set 9 | kud
# Processing Record 25 of Set 9 | makat
# Processing Record 26 of Set 9 | sangmelima
# Processing Record 27 of Set 9 | zaraza
# Processing Record 28 of Set 9 | colares
# Processing Record 29 of Set 9 | gongzhuling
# Processing Record 30 of Set 9 | sosua
# Processing Record 31 of Set 9 | lamar
# Processing Record 32 of Set 9 | odweyne
# Processing Record 33 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 9 | aras
# Processing Record 35 of Set 9 | jumla
# Processing Record 36 of Set 9 | san vicente
# Processing Record 37 of Set 9 | afua
# Processing Record 38 of Set 9 | belousovka
# Processing Record 39 of Set 9 | mantua
# Processing Record 40 of Set 9 | rockland
# Processing Record 41 of Set 9 | mitsamiouli
# Processing Record 42 of Set 9 | broome
# Processing Record 43 of Set 9 | bilma
# Processing Record 44 of Set 9 | nizwa
# Processing Record 45 of Set 9 | panalingaan
# Processing Record 46 of Set 9 | cayhagan
# Processing Record 47 of Set 9 | shimoda
# Processing Record 48 of Set 9 | ballina
# Processing Record 49 of Set 9 | fulitun
# City not found. Skipping...
# Processing Record 50 of Set 9 | willowmore
# Processing Record 1 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 2 of Set 10 | gizo
# Processing Record 3 of Set 10 | richards bay
# Processing Record 4 of Set 10 | nsanje
# Processing Record 5 of Set 10 | mimongo
# Processing Record 6 of Set 10 | cedar hill
# Processing Record 7 of Set 10 | sukhumi
# Processing Record 8 of Set 10 | cam ranh
# Processing Record 9 of Set 10 | la orilla
# Processing Record 10 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 10 | kandava
# Processing Record 12 of Set 10 | grafton
# Processing Record 13 of Set 10 | egvekinot
# Processing Record 14 of Set 10 | binzhou
# Processing Record 15 of Set 10 | kimbe
# Processing Record 16 of Set 10 | marsa matruh
# Processing Record 17 of Set 10 | lasa
# Processing Record 18 of Set 10 | lanzhou
# Processing Record 19 of Set 10 | kovdor
# Processing Record 20 of Set 10 | ati
# Processing Record 21 of Set 10 | beloha
# Processing Record 22 of Set 10 | visnes
# Processing Record 23 of Set 10 | srandakan
# Processing Record 24 of Set 10 | ribeira grande
# Processing Record 25 of Set 10 | gornopravdinsk
# Processing Record 26 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 10 | rundu
# Processing Record 28 of Set 10 | oistins
# Processing Record 29 of Set 10 | guljanci
# City not found. Skipping...
# Processing Record 30 of Set 10 | tianpeng
# Processing Record 31 of Set 10 | itoman
# Processing Record 32 of Set 10 | gorodishche
# Processing Record 33 of Set 10 | monterey
# Processing Record 34 of Set 10 | sahbuz
# Processing Record 35 of Set 10 | acapulco
# Processing Record 36 of Set 10 | orange cove
# Processing Record 37 of Set 10 | puerto ayacucho
# Processing Record 38 of Set 10 | seredka
# Processing Record 39 of Set 10 | azovo
# Processing Record 40 of Set 10 | parana
# Processing Record 41 of Set 10 | darhan
# Processing Record 42 of Set 10 | kiruna
# Processing Record 43 of Set 10 | tshikapa
# Processing Record 44 of Set 10 | churu
# Processing Record 45 of Set 10 | los llanos de aridane
# Processing Record 46 of Set 10 | pokrovsk
# Processing Record 47 of Set 10 | beaverlodge
# Processing Record 48 of Set 10 | caucaia
# Processing Record 49 of Set 10 | myitkyina
# Processing Record 50 of Set 10 | kawalu
# Processing Record 1 of Set 11 | canberra
# Processing Record 2 of Set 11 | pasighat
# Processing Record 3 of Set 11 | marawi
# Processing Record 4 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 11 | harper
# Processing Record 6 of Set 11 | dolores
# Processing Record 7 of Set 11 | jaipur hat
# City not found. Skipping...
# Processing Record 8 of Set 11 | chinsali
# Processing Record 9 of Set 11 | amelia
# Processing Record 10 of Set 11 | turiacu
# Processing Record 11 of Set 11 | vitimskiy
# City not found. Skipping...
# Processing Record 12 of Set 11 | matameye
# City not found. Skipping...
# Processing Record 13 of Set 11 | makakilo city
# Processing Record 14 of Set 11 | adrar
# Processing Record 15 of Set 11 | kedrovyy
# Processing Record 16 of Set 11 | cabedelo
# Processing Record 17 of Set 11 | lawton
# Processing Record 18 of Set 11 | dubrovytsya
# Processing Record 19 of Set 11 | grindavik
# Processing Record 20 of Set 11 | griffith
# Processing Record 21 of Set 11 | mashhad
# Processing Record 22 of Set 11 | mao
# Processing Record 23 of Set 11 | lasem
# Processing Record 24 of Set 11 | nouadhibou
# Processing Record 25 of Set 11 | neuquen
# Processing Record 26 of Set 11 | mahanoro
# Processing Record 27 of Set 11 | havelock
# Processing Record 28 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 11 | aranos
# Processing Record 30 of Set 11 | palembang
# Processing Record 31 of Set 11 | smithers
# Processing Record 32 of Set 11 | shancheng
# Processing Record 33 of Set 11 | ewa beach
# Processing Record 34 of Set 11 | madang
# Processing Record 35 of Set 11 | dawson creek
# Processing Record 36 of Set 11 | alofi
# Processing Record 37 of Set 11 | flinders
# Processing Record 38 of Set 11 | wakkanai
# Processing Record 39 of Set 11 | hirara
# Processing Record 40 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 11 | maceio
# Processing Record 42 of Set 11 | tomakomai
# Processing Record 43 of Set 11 | bhairab bazar
# Processing Record 44 of Set 11 | grand gaube
# Processing Record 45 of Set 11 | linares
# Processing Record 46 of Set 11 | ust-kuyga
# Processing Record 47 of Set 11 | haimen
# Processing Record 48 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 11 | hualmay
# Processing Record 50 of Set 11 | verkh-suetka
# Processing Record 1 of Set 12 | vostok
# Processing Record 2 of Set 12 | cooma
# Processing Record 3 of Set 12 | san juan
# Processing Record 4 of Set 12 | la libertad
# Processing Record 5 of Set 12 | volkhov
# Processing Record 6 of Set 12 | linxia
# Processing Record 7 of Set 12 | eyl
# Processing Record 8 of Set 12 | tiarei
# Processing Record 9 of Set 12 | atlantis
# Processing Record 10 of Set 12 | agadir
# Processing Record 11 of Set 12 | traverse city
# Processing Record 12 of Set 12 | zyryanka
# Processing Record 13 of Set 12 | huixtla
# Processing Record 14 of Set 12 | cayenne
# Processing Record 15 of Set 12 | umea
# Processing Record 16 of Set 12 | kenai
# Processing Record 17 of Set 12 | mbandaka
# Processing Record 18 of Set 12 | cananeia
# Processing Record 19 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 12 | osorno
# Processing Record 21 of Set 12 | badiraguato
# Processing Record 22 of Set 12 | preston
# Processing Record 23 of Set 12 | sinnamary
# Processing Record 24 of Set 12 | boende
# Processing Record 25 of Set 12 | hamilton
# Processing Record 26 of Set 12 | tessalit
# Processing Record 27 of Set 12 | beringovskiy
# Processing Record 28 of Set 12 | vazante
# Processing Record 29 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 12 | muravlenko
# Processing Record 32 of Set 12 | uspantan
# Processing Record 33 of Set 12 | hammerfest
# Processing Record 34 of Set 12 | san andres
# Processing Record 35 of Set 12 | baijiantan
# Processing Record 36 of Set 12 | inhambane
# Processing Record 37 of Set 12 | naliya
# Processing Record 38 of Set 12 | nome
# Processing Record 39 of Set 12 | lodja
# Processing Record 40 of Set 12 | flin flon
# Processing Record 41 of Set 12 | fairbanks
# Processing Record 42 of Set 12 | tokur
# Processing Record 43 of Set 12 | kaputa
# Processing Record 44 of Set 12 | netolice
# Processing Record 45 of Set 12 | la romana
# Processing Record 46 of Set 12 | pombia
# Processing Record 47 of Set 12 | yefremov
# Processing Record 48 of Set 12 | saint-georges
# Processing Record 49 of Set 12 | gorele
# Processing Record 50 of Set 12 | caravelas
# Processing Record 1 of Set 13 | el cope
# Processing Record 2 of Set 13 | saint-pierre
# Processing Record 3 of Set 13 | burnie
# Processing Record 4 of Set 13 | mahajanga
# Processing Record 5 of Set 13 | gwadar
# Processing Record 6 of Set 13 | malanje
# Processing Record 7 of Set 13 | lethem
# Processing Record 8 of Set 13 | zhanaozen
# Processing Record 9 of Set 13 | mandera
# Processing Record 10 of Set 13 | mitu
# Processing Record 11 of Set 13 | yadgir
# Processing Record 12 of Set 13 | sakakah
# Processing Record 13 of Set 13 | natchitoches
# Processing Record 14 of Set 13 | virginia beach
# Processing Record 15 of Set 13 | shangzhi
# Processing Record 16 of Set 13 | wolmirstedt
# Processing Record 17 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 13 | baishishan
# Processing Record 19 of Set 13 | yumen
# Processing Record 20 of Set 13 | ixtapa
# Processing Record 21 of Set 13 | itaituba
# Processing Record 22 of Set 13 | pastavy
# Processing Record 23 of Set 13 | ciudad bolivar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 576

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town      ZA -33.9258   18.4232     79.12        71          40
# 1        Avarua      CK -21.2078 -159.7750     75.25        69          40
# 2   Port Alfred      ZA -33.5906   26.8910     70.18        93          97
# 3    Butaritari      KI   3.0707  172.7902     81.05        72          49
# 4      Kingaroy      AU -26.5333  151.8333     59.76        99          46
# 5   Purbalingga      ID  -7.3881  109.3639     75.90        92          98
# 6    Skibbereen      IE  51.5500   -9.2667     34.11        82           3
# 7     Oriximina      BR  -1.7656  -55.8661     90.45        44          70
# 8  Port Moresby      PG  -9.4431  147.1797     74.62       100          40
# 9        Lompoc      US  34.6391 -120.4579     54.79        86          75
#
#    Wind Speed           Current Description
# 0       18.41  thunderstorm with light rain
# 1        5.75              scattered clouds
# 2        8.01               overcast clouds
# 3       12.39              scattered clouds
# 4        3.13              scattered clouds
# 5        1.16               overcast clouds
# 6        4.43                     clear sky
# 7        5.23                 broken clouds
# 8       11.50                           fog
# 9        8.05                 broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.9258   18.4232     79.12        71          40
# 1       Avarua      CK -21.2078 -159.7750     75.25        69          40
# 2  Port Alfred      ZA -33.5906   26.8910     70.18        93          97
# 3   Butaritari      KI   3.0707  172.7902     81.05        72          49
# 4     Kingaroy      AU -26.5333  151.8333     59.76        99          46
#
#    Wind Speed           Current Description
# 0       18.41  thunderstorm with light rain
# 1        5.75              scattered clouds
# 2        8.01               overcast clouds
# 3       12.39              scattered clouds
# 4        3.13              scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
